# %% [markdown]
# #### Create new harbour project and add user "jenkins" as developer, and copy the project name in namespace

# %%
#TODO: Automatically rename all namespaces in yml files
#TODO: Describe gulp and add jenkins
#TODO: Open docker/docker-compose.yml and change ports automatically

# %%
namespace = "namespacetest"
wordpress_local_port = 1234
mysql_local_port = 1235

# %% [markdown]
# # Setting up local enviroment

# %%
# !docker login reg.xailabs.com
# Out:
# Authenticating with existing credentials...
# Login Succeeded

# %%
# %cd docker
# Out:
# /Users/killingzoe/Documents/xailabs/jupyter-wordpress-template/docker

# %%
# !docker-compose build
# Out:
# template-postfix uses an image, skipping
# template-mysql uses an image, skipping
# Building template-wordpress
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
# [+] Building 0.4s (11/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
# [+] Building 0.5s (11/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.1s
# [+] Building 0.7s (11/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.3s
# [+] Building 0.8s (11/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.4s
# [+] Building 1.0s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
# [+] Building 1.1s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.1s
# [+] Building 1.3s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.3s
# [+] Building 1.4s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.5s
# [+] Building 1.6s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.6s
# [+] Building 1.7s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.8s
# [+] Building 1.9s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     0.9s
# [+] Building 2.0s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.1s
# [+] Building 2.2s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.2s
# [+] Building 2.3s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.4s
# [+] Building 2.5s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.5s
# [+] Building 2.6s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.7s
# [+] Building 2.8s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     1.8s
# [+] Building 2.9s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.0s
# [+] Building 3.1s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.1s
# [+] Building 3.2s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.3s
# [+] Building 3.4s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.4s
# [+] Building 3.5s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.6s
# [+] Building 3.7s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.7s
# [+] Building 3.8s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     2.9s
# [+] Building 4.0s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.0s
# [+] Building 4.2s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.2s
# [+] Building 4.3s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.3s
# [+] Building 4.5s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.5s
# [+] Building 4.6s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.7s
# [+] Building 4.8s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     3.8s
# [+] Building 4.9s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     4.0s
# [+] Building 5.1s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     4.1s
# [+] Building 5.2s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     4.3s
# [+] Building 5.4s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     4.4s
# [+] Building 5.5s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
# ...
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 11.0s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 11.2s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 11.3s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 11.5s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 11.6s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.6s
# [+] Building 11.8s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 11.9s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 12.1s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 12.2s (13/14)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     2.2s
#  => => exporting layers                                                    2.2s
# [+] Building 12.3s (14/14) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 883B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for reg.xailabs.com/xailabs/wordpress:latest  0.0s
#  => [1/9] FROM reg.xailabs.com/xailabs/wordpress:latest                    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 35.24kB                                       0.1s
#  => CACHED [2/9] RUN apt-get update && apt-get upgrade -y && apt-get clea  0.0s
#  => CACHED [3/9] RUN rm -rf wp-content/themes/                             0.0s
#  => CACHED [4/9] COPY wp-content/themes/ /var/www/html/wp-content/themes/  0.0s
#  => CACHED [5/9] COPY wp-content/plugins/advanced-custom-fields-pro/ /var  0.0s
#  => CACHED [6/9] COPY docker/wordpress/favicon.ico /var/www/html/favicon.  0.0s
#  => [7/9] COPY docker/wordpress/w3tc-config /var/www/html/wp-content/w3tc  0.1s
#  => [8/9] RUN chmod 777 /var/www/html/wp-content/w3tc-config               0.6s
#  => [9/9] RUN chown -R www-data:www-data /var/www/html                     9.0s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    2.2s
#  => => writing image sha256:0979377ad87eaac7e6f861663a8d16e9069a6b87c9441  0.0s
#  => => naming to reg.xailabs.com/xailabs/wordpress:latest                  0.0s
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them

# %%
# !docker network create template-network
# Out:
# ef79a6760c18281e847090e51da66c0aaa53c89e2d8556549346787dd3de01c6

# %%
# !docker-compose up -d
# Out:
# Docker Compose is now in the Docker CLI, try `docker compose up`
#
# WARNING: Found orphan containers (docker_pictofolio-php_1, docker_pictofolio-mariadb_1, docker_pictofolio-nginx_1) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# Pulling template-postfix (reg.xailabs.com/xailabs/postfix:latest)...
# latest: Pulling from xailabs/postfix
#
# b700ef54: Pulling fs layer
# 0c8b6033: Pulling fs layer
# 8aaec31e: Pulling fs layer
# 4bc3a8ca: Pulling fs layer
# 4d98dd14: Pulling fs layer
# 31049e1f: Pulling fs layer
# fa98fb48: Pulling fs layer
# 886f29e3: Pulling fs layer
# e84d31a6: Pulling fs layer
# 278130f5: Pulling fs layer
# 4a87804e: Pulling fs layer
# 1e23f665: Pulling fs layer
# 0fb94162: Pulling fs layer
# e89f3ebd: Pulling fs layer
# 84012224: Pulling fs layer
# Digest: sha256:394f42fd8f663b341ab70e2f0072b6f85725bbacdb81ad39196cb026889c8cbb    206B/206BMBBBA
# Status: Downloaded newer image for reg.xailabs.com/xailabs/postfix:latest
# Creating docker_template-mysql_1 ...
# Creating docker_template-postfix_1 ...
# Creating docker_template-wordpress_1 ...
# ting docker_template-mysql_1     ... done

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                              COMMAND                  CREATED          STATUS          PORTS                                                  NAMES
# b69b4ae97372   reg.xailabs.com/xailabs/wordpress:latest           "docker-entrypoint.s…"   17 minutes ago   Up 17 minutes   0.0.0.0:1234->80/tcp, :::1234->80/tcp                  docker_template-wordpress_1
# 59159e777258   reg.xailabs.com/xailabs/postfix:latest             "/bin/sh -c /docker_…"   17 minutes ago   Up 17 minutes                                                          docker_template-postfix_1
# 110e06d2138e   reg.xailabs.com/xailabs/mysql:5.7                  "docker-entrypoint.s…"   17 minutes ago   Up 17 minutes   33060/tcp, 0.0.0.0:1235->3306/tcp, :::1235->3306/tcp   docker_template-mysql_1
# 694564d336c1   reg.xailabs.com/pictofolio/pictofolio-php:latest   "docker-php-entrypoi…"   5 weeks ago      Up 3 days       9000/tcp                                               docker_pictofolio-php_1
# fc3923f59534   reg.xailabs.com/xailabs/mysql:8.0.18               "docker-entrypoint.s…"   5 weeks ago      Up 3 days       33060/tcp, 0.0.0.0:7778->3306/tcp, :::7778->3306/tcp   docker_pictofolio-mariadb_1

# %% [markdown]
# # Setting up the deployment server

# %%
# %cd kubernetes
# Out:
# /Users/killingzoe/Documents/xailabs/jupyter-wordpress-template/docker/kubernetes

# %%
# !docker tag reg.xailabs.com/xailabs/wordpress:latest reg.xailabs.com/{namespace}/wordpress:latest

# %%
# !docker push reg.xailabs.com/{namespace}/wordpress:latest
# Out:
# The push refers to repository [reg.xailabs.com/jupytertest/wordpress]
#
# 610b235d: Preparing
# debaee68: Preparing
# 317ccfeb: Preparing
# 3f3116cb: Preparing
# f160bea1: Preparing
# 0279b846: Preparing
# de8e3216: Preparing
# 00f18d3a: Preparing
# e354cbc3: Preparing
# 9db097da: Preparing
# 3bff95b9: Preparing
# 47537ebf: Preparing
# 4dea85fa: Preparing
# 4ea1e458: Preparing
# e8123cc2: Preparing
# 9e2b0737: Preparing
# 331bab2c: Preparing
# ce389e32: Preparing
# 69bd88d3: Preparing
# 337b9a55: Preparing
# 7b4dd485: Preparing
# 9e9c9e58: Preparing
# 35927b5a: Preparing
# 39edfbf0: Preparing
# f89886ba: Preparing
# 865e86e9: Preparing
# 5e569df9: Preparing
# 5e569df9: Mounted from holy-everest/wordpress latest: digest: sha256:d703f42af4769bcd9d249bf1287036cd4fb88a92afbb4ac8d40c707f7ea53adb size: 6163

# %%
# !kubectl apply -f namespace.yml
# Out:
# namespace/jupytertest-template created

# %%
# !kubectl config set-context xailabs-dev --namespace {namespace}
# Out:
# Context "xailabs-dev" modified.

# %%
# !kubectl config use-context xailabs-dev
# Out:
# Switched to context "xailabs-dev".

# %%
# !kubectl apply -f glusterfs.yml
# Out:
# service/glusterfs-cluster created
# endpoints/glusterfs-cluster created

# %%
# !kubectl get secret
# Out:
# NAME                  TYPE                                  DATA   AGE
# default-token-pddbb   kubernetes.io/service-account-token   3      63d
# template-wp-config    Opaque                                1      62d
# xairegcred            kubernetes.io/dockerconfigjson        1      63d

# %%
# !kubectl create secret generic template-wp-config  --from-file=../wordpress/wp-config-stage.php
# Out:
# secret/template-wp-config created

# %%
# !kubectl apply -f xairegcred.yml
# Out:
# secret/xairegcred created

# %%
# !kubectl apply -f deployment.yml
# Out:
# deployment.apps/template-wordpress configured
# deployment.apps/template-mysql configured
# deployment.apps/template-postfix configured

# %%
# !kubectl apply -f service.yml
# Out:
# service/template-wordpress created
# service/template-mysql created
# service/template-postfix created

# %%
# !kubectl apply -f ingress.yml
# Out:
# ingress.extensions/template-wordpress created

# %%
# !kubectl get all
# Out:
# NAME                                     READY   STATUS    RESTARTS   AGE
# pod/jupytertest-mysql-7d695988df-9bwx7   1/1     Running   7          23m
# pod/template-mysql-5475d474ff-dn6j5      1/1     Running   0          63d
# pod/template-postfix-58f69899c9-t44n9    1/1     Running   0          63d
# pod/template-wordpress-dd5cf954c-thqc2   1/1     Running   0          32m
#
# NAME                         TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)        AGE
# service/glusterfs-cluster    ClusterIP   10.96.144.56    <none>        1/TCP          63d
# service/template-mysql       ClusterIP   10.96.144.219   <none>        3306/TCP       63d
# service/template-postfix     ClusterIP   10.96.44.238    <none>        25/TCP         63d
# service/template-wordpress   NodePort    10.96.160.210   <none>        80:31187/TCP   63d
#
# NAME                                 READY   UP-TO-DATE   AVAILABLE   AGE
# deployment.apps/jupytertest-mysql    1/1     1            1           23m
# deployment.apps/template-mysql       1/1     1            1           63d
# deployment.apps/template-postfix     1/1     1            1           63d
# deployment.apps/template-wordpress   1/1     1            1           63d
#
# NAME                                            DESIRED   CURRENT   READY   AGE
# replicaset.apps/jupytertest-mysql-7d695988df    1         1         1       23m
# replicaset.apps/template-mysql-5475d474ff       1         1         1       63d
# replicaset.apps/template-postfix-58f69899c9     1         1         1       63d
# replicaset.apps/template-wordpress-5d7fcb5685   0         0         0       63d
# replicaset.apps/template-wordpress-64989689dc   0         0         0       62d
# replicaset.apps/template-wordpress-6b5f466479   0         0         0       62d
# replicaset.apps/template-wordpress-76795b7c65   0         0         0       19h
# replicaset.apps/template-wordpress-79df95d498   0         0         0       62d
# replicaset.apps/template-wordpress-7cbf9cbcc5   0         0         0       63d
# replicaset.apps/template-wordpress-866898c695   0         0         0       62d
# replicaset.apps/template-wordpress-bdd977ffb    0         0         0       63d
# replicaset.apps/template-wordpress-c7444b7dd    0         0         0       63d
# replicaset.apps/template-wordpress-dd5cf954c    1         1         1       32m

# %% [markdown]
# # Problems?
# #### If no user jenkins in harbour, or also when a new wordpress version is present

# %%
# !kubectl rollout restart deployment/template-wordpress
# Out:
# deployment.apps/template-wordpress restarted

# %% [markdown]
# #### To reset the container

# %%
# !docker-compose down

# %% [markdown]
# #### If you change dockerfile or if new wordpress is available

# %%
# !docker-compose pull
# !docker-compose build

# %% [markdown]
# #### Copy config in root .kube, download file (let's fix it later)
